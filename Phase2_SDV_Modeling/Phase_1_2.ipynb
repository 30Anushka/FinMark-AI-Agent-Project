# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
pip install faker pandas numpy
# Out:
# Requirement already satisfied: faker in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (37.8.0)
# Requirement already satisfied: pandas in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: tzdata in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from faker) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from faker import Faker
import random
import os

# Initialize Faker
fake = Faker('en_IN')

# Parameters
n_customers = 2000
job_roles = ["Software Engineer", "Consultant", "Banker", "Designer", "Sales", "Data Scientist", "Product Manager"]
employment_types = ["Salaried", "Contract", "Freelance"]
cities = ["Mumbai", "Bengaluru", "Delhi", "Hyderabad", "Chennai", "Pune", "Gurugram", "Kolkata"]

# === Save directly to Downloads folder ===
downloads_dir = os.path.join(os.path.expanduser("~"), "Downloads", "synthetic_data")
os.makedirs(downloads_dir, exist_ok=True)

# Generate customer profiles
customer_data = []
for i in range(1, n_customers + 1):
    age = random.randint(23, 40)
    gender = random.choice(["Male", "Female", "Non-binary"])
    city = random.choice(cities)
    job = random.choice(job_roles)
    employment_type = random.choice(employment_types)
    income = random.randint(300000, 2000000)
    credit_score = random.randint(300, 850)
    savings_rate = round(random.uniform(0, 0.6), 2)
    existing_loan_balance = random.choice([0, random.randint(50000, 1000000)])
    account_balance = random.randint(1000, 500000)
    joined_date = fake.date_between(start_date="-5y", end_date="today")

    customer_data.append([
        i, age, gender, city, job, employment_type, income,
        credit_score, savings_rate, existing_loan_balance,
        account_balance, joined_date
    ])

customers_df = pd.DataFrame(customer_data, columns=[
    "customer_id", "age", "gender", "city", "job_role", "employment_type",
    "income", "credit_score", "savings_rate", "existing_loan_balance",
    "account_balance", "joined_date"
])

# Transactions
transaction_categories = ["Rent", "Groceries", "Entertainment", "Travel", "Investment", "Dining"]
transactions = []
for cust_id in customers_df['customer_id']:
    num_txns = random.randint(10, 50)
    for _ in range(num_txns):
        txn_date = fake.date_between(start_date="-1y", end_date="today")
        category = random.choice(transaction_categories)
        amount = round(random.uniform(500, 50000), 2)
        transactions.append([cust_id, txn_date, category, amount])

transactions_df = pd.DataFrame(transactions, columns=[
    "customer_id", "transaction_date", "category", "amount"
])

# Campaign Events
campaign_responses = ["Opened", "Clicked", "Converted", "Ignored"]
campaigns = []
for cust_id in customers_df['customer_id']:
    num_events = random.randint(1, 5)
    for _ in range(num_events):
        event_date = fake.date_between(start_date="-6m", end_date="today")
        response = random.choices(campaign_responses, weights=[0.4, 0.3, 0.2, 0.1])[0]
        campaigns.append([cust_id, event_date, response])

campaigns_df = pd.DataFrame(campaigns, columns=[
    "customer_id", "event_date", "response"
])

# Save files in Downloads
customers_file = os.path.join(downloads_dir, "customers.csv")
transactions_file = os.path.join(downloads_dir, "transactions.csv")
campaigns_file = os.path.join(downloads_dir, "campaign_events.csv")

customers_df.to_csv(customers_file, index=False)
transactions_df.to_csv(transactions_file, index=False)
campaigns_df.to_csv(campaigns_file, index=False)

print(f"✅ Files saved in your Downloads folder: {downloads_dir}")
print(f"- {customers_file}")
print(f"- {transactions_file}")
print(f"- {campaigns_file}")
# Out:
# ✅ Files saved in your Downloads folder: C:\Users\user\Downloads\synthetic_data
# - C:\Users\user\Downloads\synthetic_data\customers.csv
# - C:\Users\user\Downloads\synthetic_data\transactions.csv
# - C:\Users\user\Downloads\synthetic_data\campaign_events.csv

# %%
pip install sdv
# Out:
# Requirement already satisfied: sdv in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (1.27.0)
# Requirement already satisfied: boto3<2.0.0,>=1.28 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from sdv) (1.40.44)
# Requirement already satisfied: botocore<2.0.0,>=1.31 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from sdv) (1.40.44)
# Requirement already satisfied: cloudpickle>=2.1.0 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from sdv) (3.1.1)
# Requirement already satisfied: graphviz>=0.13.2 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from sdv) (0.21)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from sdv) (2.3.3)
# Requirement already satisfied: pandas>=2.2.3 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from sdv) (2.3.3)
# Requirement already satisfied: tqdm>=4.29 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from sdv) (4.67.1)
# Requirement already satisfied: copulas>=0.12.1 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from sdv) (0.12.3)
# Requirement already satisfied: ctgan>=0.11.0 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from sdv) (0.11.0)
# Requirement already satisfied: deepecho>=0.7.0 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from sdv) (0.7.0)
# Requirement already satisfied: rdt>=1.17.0 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from sdv) (1.18.1)
# Requirement already satisfied: sdmetrics>=0.21.0 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from sdv) (0.23.0)
# Requirement already satisfied: platformdirs>=4.0 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from sdv) (4.4.0)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from sdv) (6.0.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from boto3<2.0.0,>=1.28->sdv) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from boto3<2.0.0,>=1.28->sdv) (0.14.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from botocore<2.0.0,>=1.31->sdv) (2.5.0)
# Requirement already satisfied: plotly>=5.12.0 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from copulas>=0.12.1->sdv) (6.3.1)
# Requirement already satisfied: scipy>=1.14.1 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from copulas>=0.12.1->sdv) (1.16.2)
# Requirement already satisfied: torch>=2.6.0 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from ctgan>=0.11.0->sdv) (2.8.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from pandas>=2.2.3->sdv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from pandas>=2.2.3->sdv) (2025.2)
# Requirement already satisfied: scikit-learn>=1.5.2 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from rdt>=1.17.0->sdv) (1.7.2)
# Requirement already satisfied: Faker>=17 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from rdt>=1.17.0->sdv) (37.8.0)
# Requirement already satisfied: colorama in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from tqdm>=4.29->sdv) (0.4.6)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from plotly>=5.12.0->copulas>=0.12.1->sdv) (2.6.0)
# Requirement already satisfied: packaging in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from plotly>=5.12.0->copulas>=0.12.1->sdv) (25.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from scikit-learn>=1.5.2->rdt>=1.17.0->sdv) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from scikit-learn>=1.5.2->rdt>=1.17.0->sdv) (3.6.0)
# Requirement already satisfied: filelock in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from torch>=2.6.0->ctgan>=0.11.0->sdv) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from torch>=2.6.0->ctgan>=0.11.0->sdv) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from torch>=2.6.0->ctgan>=0.11.0->sdv) (1.14.0)
# Requirement already satisfied: networkx in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from torch>=2.6.0->ctgan>=0.11.0->sdv) (3.5)
# Requirement already satisfied: jinja2 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from torch>=2.6.0->ctgan>=0.11.0->sdv) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from torch>=2.6.0->ctgan>=0.11.0->sdv) (2025.9.0)
# Requirement already satisfied: setuptools in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from torch>=2.6.0->ctgan>=0.11.0->sdv) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from sympy>=1.13.3->torch>=2.6.0->ctgan>=0.11.0->sdv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\pycharmmiscproject\.venv\lib\site-packages (from jinja2->torch>=2.6.0->ctgan>=0.11.0->sdv) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sdv
print(sdv.__version__)
# Out:
# 1.27.0

# %%
from sdv.single_table import CTGANSynthesizer
from sdv.multi_table import HMASynthesizer

print("CTGAN and HMA Synthesizer are available ✅")
# Out:
# CTGAN and HMA Synthesizer are available ✅

# %%
# ctgan_full.py
import os
import pandas as pd
import numpy as np
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import SingleTableMetadata
import argparse
import time

# ---------- Config ----------
# Set DEBUG=True for quick runs (faster, fewer rows/epochs)
DEBUG = False

DOWNLOADS_DIR = os.path.join(os.path.expanduser("~"), "Downloads", "synthetic_data")
os.makedirs(DOWNLOADS_DIR, exist_ok=True)
SEED_CUST_PATH = os.path.join(DOWNLOADS_DIR, "customers.csv")  # from Phase 1

# CTGAN params
if DEBUG:
    N_SYNTH = 500
    EPOCHS = 50
else:
    N_SYNTH = 10000
    EPOCHS = 300

# ---------- Load seed ----------
print("Loading seed customers from:", SEED_CUST_PATH)
customers_df = pd.read_csv(SEED_CUST_PATH, parse_dates=['joined_date'])

# ---------- Metadata ----------
print("Detecting metadata...")
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(data=customers_df)

# Ensure joined_date is recognized as datetime if present
if 'joined_date' in customers_df.columns:
    try:
        metadata.update_column('joined_date', sdtype='datetime')
    except Exception:
        pass

# ---------- Train CTGAN ----------
print(f"Initializing CTGAN (epochs={EPOCHS}) — training may take time...")
start = time.time()
synth = CTGANSynthesizer(metadata=metadata, epochs=EPOCHS)
synth.fit(customers_df)
print("Training finished in %.1f seconds" % (time.time() - start))

# ---------- Sample ----------
print(f"Sampling {N_SYNTH} synthetic customers...")
synthetic_customers = synth.sample(N_SYNTH)

# Postprocess: ensure customer_id unique numeric incremental
synthetic_customers = synthetic_customers.reset_index(drop=True)
synthetic_customers['customer_id'] = np.arange(1, len(synthetic_customers) + 1)

# Save
out_file = os.path.join(DOWNLOADS_DIR, f"customers_ctgan_{N_SYNTH}.csv")
synthetic_customers.to_csv(out_file, index=False)
print("Saved:", out_file)
# Out:
# Loading seed customers from: C:\Users\user\Downloads\synthetic_data\customers.csv
# Detecting metadata...
# Initializing CTGAN (epochs=300) — training may take time...
# C:\Users\user\PyCharmMiscProject\.venv\Lib\site-packages\sdv\single_table\base.py:168: FutureWarning:
#
# The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#
# C:\Users\user\PyCharmMiscProject\.venv\Lib\site-packages\sdv\single_table\base.py:134: UserWarning:
#
# We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# Training finished in 65.6 seconds
# Sampling 10000 synthetic customers...
# Saved: C:\Users\user\Downloads\synthetic_data\customers_ctgan_10000.csv

# %%
# hma_full.py
import os
import pandas as pd
from sdv.multi_table import HMASynthesizer
from sdv.metadata import Metadata
import time

# ---------- Config ----------
DEBUG = False  # set True for faster debug

DOWNLOADS_DIR = os.path.join(os.path.expanduser("~"), "Downloads", "synthetic_data")
os.makedirs(DOWNLOADS_DIR, exist_ok=True)

# Seed file paths (Phase 1)
CUSTOMERS_PATH = os.path.join(DOWNLOADS_DIR, "customers.csv")
TRANSACTIONS_PATH = os.path.join(DOWNLOADS_DIR, "transactions.csv")
CAMPAIGNS_PATH = os.path.join(DOWNLOADS_DIR, "campaign_events.csv")

# Output sizes
if DEBUG:
    N_CUSTOMERS = 500
else:
    N_CUSTOMERS = 10000

# ---------- Load seed ----------
print("Loading seed tables...")
customers = pd.read_csv(CUSTOMERS_PATH, parse_dates=['joined_date'])
transactions = pd.read_csv(TRANSACTIONS_PATH, parse_dates=['transaction_date'])
campaigns = pd.read_csv(CAMPAIGNS_PATH, parse_dates=['event_date'])

# ---------- Metadata ----------
print("Building multi-table metadata...")
metadata = Metadata()
# Detect tables automatically
metadata.detect_table_from_dataframe(table_name='customers', data=customers)
metadata.detect_table_from_dataframe(table_name='transactions', data=transactions)
metadata.detect_table_from_dataframe(table_name='campaigns', data=campaigns)

# Define relationships (parent -> child)
# Make sure column names match your CSVs
metadata.add_relationship(
    parent_table_name='customers',
    parent_primary_key='customer_id',
    child_table_name='transactions',
    child_foreign_key='customer_id'
)
metadata.add_relationship(
    parent_table_name='customers',
    parent_primary_key='customer_id',
    child_table_name='campaigns',
    child_foreign_key='customer_id'
)

# ---------- Initialize HMA ----------
print("Initializing HMASynthesizer (this may take time)...")
hma = HMASynthesizer(metadata)

# Optionally: set specific synthesizers per table for speed/quality
# Example: use CTGAN for customers and Gaussian for big transactions
# hma.set_table_parameters('customers', synthesizer_cls='CTGANSynthesizer')
# hma.set_table_parameters('transactions', synthesizer_cls='GaussianCopulaSynthesizer')

# ---------- Train ----------
print("Training HMA on multi-table seed...")
start = time.time()
hma.fit({
    'customers': customers,
    'transactions': transactions,
    'campaigns': campaigns
})
print("HMA training finished in %.1f seconds" % (time.time() - start))

# ---------- Sample ----------
print(f"Sampling multi-table dataset with {N_CUSTOMERS} customers...")
synthetic_multi = hma.sample(scale=5)

# Extract tables
syn_customers = synthetic_multi['customers']
syn_transactions = synthetic_multi['transactions']
syn_campaigns = synthetic_multi['campaigns']

# Save outputs
out_customers = os.path.join(DOWNLOADS_DIR, f"customers_hma_{N_CUSTOMERS}.csv")
out_transactions = os.path.join(DOWNLOADS_DIR, f"transactions_hma_{N_CUSTOMERS}.csv")
out_campaigns = os.path.join(DOWNLOADS_DIR, f"campaigns_hma_{N_CUSTOMERS}.csv")

syn_customers.to_csv(out_customers, index=False)
syn_transactions.to_csv(out_transactions, index=False)
syn_campaigns.to_csv(out_campaigns, index=False)

print("Saved HMA outputs to:", DOWNLOADS_DIR)
print("-", out_customers)
print("-", out_transactions)
print("-", out_campaigns)
# Out:
# Loading seed tables...
# Building multi-table metadata...
# Initializing HMASynthesizer (this may take time)...
# Training HMA on multi-table seed...
# C:\Users\user\PyCharmMiscProject\.venv\Lib\site-packages\sdv\multi_table\base.py:109: UserWarning:
#
# We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#
# Preprocess Tables: 100%|██████████| 3/3 [00:03<00:00,  1.10s/it]
# Learning relationships:
# (1/2) Tables 'customers' and 'transactions' ('customer_id'): 100%|██████████| 2000/2000 [04:46<00:00,  6.99it/s]
# (2/2) Tables 'customers' and 'campaigns' ('customer_id'): 100%|██████████| 2000/2000 [01:03<00:00, 31.47it/s]
# Modeling Tables: 100%|██████████| 3/3 [00:10<00:00,  3.40s/it]
# HMA training finished in 366.6 seconds
# Sampling multi-table dataset with 10000 customers...
# Saved HMA outputs to: C:\Users\user\Downloads\synthetic_data
# - C:\Users\user\Downloads\synthetic_data\customers_hma_10000.csv
# - C:\Users\user\Downloads\synthetic_data\transactions_hma_10000.csv
# - C:\Users\user\Downloads\synthetic_data\campaigns_hma_10000.csv

# %%
# reality_checks.py
import os
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

DOWNLOADS_DIR = os.path.join(os.path.expanduser("~"), "Downloads", "synthetic_data")
os.makedirs(DOWNLOADS_DIR, exist_ok=True)

# Choose seed and synthetic files
seed_file = os.path.join(DOWNLOADS_DIR, "customers.csv")

# Prefer CTGAN file if exists, else HMA file
ctgan_file = os.path.join(DOWNLOADS_DIR, "customers_ctgan_10000.csv")
hma_file = os.path.join(DOWNLOADS_DIR, "customers_hma_10000.csv")
debug_ctgan = os.path.join(DOWNLOADS_DIR, "customers_ctgan_debug.csv")
debug_hma = os.path.join(DOWNLOADS_DIR, "customers_hma_debug.csv")

if os.path.exists(ctgan_file):
    syn_file = ctgan_file
elif os.path.exists(hma_file):
    syn_file = hma_file
elif os.path.exists(debug_ctgan):
    syn_file = debug_ctgan
elif os.path.exists(debug_hma):
    syn_file = debug_hma
else:
    raise FileNotFoundError("No synthetic customer file found in Downloads/synthetic_data/. Run CTGAN/HMA first.")

print("Seed file:", seed_file)
print("Synthetic file:", syn_file)

seed = pd.read_csv(seed_file)
syn = pd.read_csv(syn_file)

# Numeric columns to compare
num_cols = ['income', 'credit_score', 'account_balance', 'age']

# 1) Histograms and save plots
for col in num_cols:
    if col in seed.columns and col in syn.columns:
        plt.figure(figsize=(8,4))
        plt.hist(seed[col].dropna(), bins=50, density=True, alpha=0.5, label='seed')
        plt.hist(syn[col].dropna(), bins=50, density=True, alpha=0.5, label='synthetic')
        plt.title(f'{col} distribution: seed vs synthetic')
        plt.legend()
        out_png = os.path.join(DOWNLOADS_DIR, f'{col}_dist_compare.png')
        plt.savefig(out_png)
        plt.close()
        print("Saved plot:", out_png)

# 2) KS tests
for col in ['income', 'credit_score', 'account_balance']:
    if col in seed.columns and col in syn.columns:
        ks = stats.ks_2samp(seed[col].dropna().astype(float), syn[col].dropna().astype(float))
        print(f"KS test for {col}: statistic={ks.statistic:.4f}, pvalue={ks.pvalue:.4f}")

# 3) Correlations: income vs credit_score
if set(['income','credit_score']).issubset(seed.columns) and set(['income','credit_score']).issubset(syn.columns):
    seed_corr = seed[['income','credit_score']].dropna().astype(float).corr().iloc[0,1]
    syn_corr = syn[['income','credit_score']].dropna().astype(float).corr().iloc[0,1]
    print(f"Income vs Credit Score correlation -> seed: {seed_corr:.3f}, synthetic: {syn_corr:.3f}")

    # Scatter sample for visual
    sample_seed = seed[['income','credit_score']].dropna().sample(min(1000, len(seed)), random_state=1)
    sample_syn = syn[['income','credit_score']].dropna().sample(min(1000, len(syn)), random_state=1)
    plt.figure(figsize=(6,5))
    plt.scatter(sample_seed['income'], sample_seed['credit_score'], alpha=0.35, s=10, label='seed')
    plt.scatter(sample_syn['income'], sample_syn['credit_score'], alpha=0.35, s=10, label='synthetic')
    plt.xlabel('income'); plt.ylabel('credit_score'); plt.legend()
    scatter_out = os.path.join(DOWNLOADS_DIR, 'income_vs_credit_scatter.png')
    plt.savefig(scatter_out)
    plt.close()
    print("Saved scatter:", scatter_out)

# 4) Basic aggregates
print("Seed averages:")
print(" - mean income:", seed['income'].mean(), "mean account_balance:", seed['account_balance'].mean())
print("Synthetic averages:")
print(" - mean income:", syn['income'].mean(), "mean account_balance:", syn['account_balance'].mean())

print("\nReality checks complete. Inspect PNGs in:", DOWNLOADS_DIR)
# Out:
# Seed file: C:\Users\user\Downloads\synthetic_data\customers.csv
# Synthetic file: C:\Users\user\Downloads\synthetic_data\customers_ctgan_10000.csv
# Saved plot: C:\Users\user\Downloads\synthetic_data\income_dist_compare.png
# Saved plot: C:\Users\user\Downloads\synthetic_data\credit_score_dist_compare.png
# Saved plot: C:\Users\user\Downloads\synthetic_data\account_balance_dist_compare.png
# Saved plot: C:\Users\user\Downloads\synthetic_data\age_dist_compare.png
# KS test for income: statistic=0.1270, pvalue=0.0000
# KS test for credit_score: statistic=0.2647, pvalue=0.0000
# KS test for account_balance: statistic=0.1403, pvalue=0.0000
# Income vs Credit Score correlation -> seed: 0.044, synthetic: -0.010
# Saved scatter: C:\Users\user\Downloads\synthetic_data\income_vs_credit_scatter.png
# Seed averages:
#  - mean income: 1142873.5225 mean account_balance: 252992.649
# Synthetic averages:
#  - mean income: 1285824.2098 mean account_balance: 295007.5841
#
# Reality checks complete. Inspect PNGs in: C:\Users\user\Downloads\synthetic_data

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Paths
DOWNLOADS_DIR = os.path.join(os.path.expanduser("~"), "Downloads", "synthetic_data")
seed_file = os.path.join(DOWNLOADS_DIR, "customers.csv")
synthetic_file = os.path.join(DOWNLOADS_DIR, "customers_ctgan_10000.csv")  # or customers_hma_10000.csv

# Load data
seed = pd.read_csv(seed_file)
syn = pd.read_csv(synthetic_file)

# Ensure numeric types
for col in ['income', 'credit_score', 'account_balance', 'age']:
    if col in seed.columns:
        seed[col] = pd.to_numeric(seed[col], errors='coerce')
    if col in syn.columns:
        syn[col] = pd.to_numeric(syn[col], errors='coerce')

# Plot distributions
cols = ['income', 'credit_score', 'account_balance', 'age']
for col in cols:
    if col in seed.columns and col in syn.columns:
        plt.figure(figsize=(8,5))
        plt.hist(seed[col].dropna(), bins=50, density=True, alpha=0.5, label='Seed')
        plt.hist(syn[col].dropna(), bins=50, density=True, alpha=0.5, label='Synthetic')
        plt.legend()
        plt.title(f"{col.capitalize()} Distribution (Seed vs Synthetic)")
        out_path = os.path.join(DOWNLOADS_DIR, f"{col}_distribution.png")
        plt.savefig(out_path)
        plt.close()
        print("Saved:", out_path)

# Scatterplot (Income vs Credit Score)
if 'income' in seed.columns and 'credit_score' in seed.columns:
    sample_seed = seed[['income','credit_score']].dropna().sample(min(1000, len(seed)), random_state=42)
    sample_syn = syn[['income','credit_score']].dropna().sample(min(1000, len(syn)), random_state=42)

    plt.figure(figsize=(8,6))
    plt.scatter(sample_seed['income'], sample_seed['credit_score'], alpha=0.4, label='Seed', s=10)
    plt.scatter(sample_syn['income'], sample_syn['credit_score'], alpha=0.4, label='Synthetic', s=10)
    plt.xlabel("Income")
    plt.ylabel("Credit Score")
    plt.title("Income vs Credit Score (Seed vs Synthetic)")
    plt.legend()
    scatter_path = os.path.join(DOWNLOADS_DIR, "income_vs_credit_scatter.png")
    plt.savefig(scatter_path)
    plt.close()
    print("Saved:", scatter_path)
# Out:
# Saved: C:\Users\user\Downloads\synthetic_data\income_distribution.png
# Saved: C:\Users\user\Downloads\synthetic_data\credit_score_distribution.png
# Saved: C:\Users\user\Downloads\synthetic_data\account_balance_distribution.png
# Saved: C:\Users\user\Downloads\synthetic_data\age_distribution.png
# Saved: C:\Users\user\Downloads\synthetic_data\income_vs_credit_scatter.png

# %%
# evaluate_ctgan.py
import os
import pandas as pd
from sdv.metadata import SingleTableMetadata
from sdv.evaluation.single_table import evaluate_quality

# ---------- File paths ----------
DOWNLOADS_DIR = os.path.join(os.path.expanduser("~"), "Downloads", "synthetic_data")
REAL_PATH = os.path.join(DOWNLOADS_DIR, "customers.csv")                 # seed (Phase 1)
SYNTH_PATH = os.path.join(DOWNLOADS_DIR, "customers_ctgan_10000.csv")   # CTGAN output

# ---------- Load data ----------
real_data = pd.read_csv(REAL_PATH)
synthetic_data = pd.read_csv(SYNTH_PATH)

# ---------- Metadata ----------
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(data=real_data)

# ---------- Evaluate ----------
score = evaluate_quality(
    real_data=real_data,
    synthetic_data=synthetic_data,
    metadata=metadata
)

print("Overall Quality Score:", score.get_score())  # 0.0–1.0
print("\nDetailed Breakdown:")
# To see details for "Column Shapes"
print("\nColumn Shapes Details:")
print(score.get_details(property_name="Column Shapes"))

# To see details for "Column Pair Trends"
print("\nColumn Pair Trends Details:")
print(score.get_details(property_name="Column Pair Trends"))
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 12/12 [00:00<00:00, 23.62it/s]|
# Column Shapes Score: 87.5%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 66/66 [00:00<00:00, 125.20it/s]|
# Column Pair Trends Score: 88.94%
#
# Overall Score (Average): 88.22%
#
# Overall Quality Score: 0.8822061548467146
#
# Detailed Breakdown:
#
# Column Shapes Details:
#                   Column        Metric   Score
# 0                    age  KSComplement  0.8621
# 1                 gender  TVComplement  0.8760
# 2               job_role  TVComplement  0.9443
# 3        employment_type  TVComplement  0.9247
# 4                 income  KSComplement  0.8730
# 5           credit_score  KSComplement  0.7353
# 6           savings_rate  KSComplement  0.9212
# 7  existing_loan_balance  KSComplement  0.8636
# 8        account_balance  KSComplement  0.8597
# 9            joined_date  KSComplement  0.8902
#
# Column Pair Trends Details:
#                  Column 1               Column 2                 Metric  \
# 0                     age                 gender  ContingencySimilarity
# 1                     age               job_role  ContingencySimilarity
# 2                     age        employment_type  ContingencySimilarity
# 3                     age                 income  CorrelationSimilarity
# 4                     age           credit_score  CorrelationSimilarity
# 5                     age           savings_rate  CorrelationSimilarity
# 6                     age  existing_loan_balance  CorrelationSimilarity
# 7                     age        account_balance  CorrelationSimilarity
# 8                     age            joined_date  CorrelationSimilarity
# 9                  gender               job_role  ContingencySimilarity
# 10                 gender        employment_type  ContingencySimilarity
# 11                 gender                 income  ContingencySimilarity
# 12                 gender           credit_score  ContingencySimilarity
# 13                 gender           savings_rate  ContingencySimilarity
# 14                 gender  existing_loan_balance  ContingencySimilarity
# 15                 gender        account_balance  ContingencySimilarity
# 16                 gender            joined_date  ContingencySimilarity
# 17               job_role        employment_type  ContingencySimilarity
# 18               job_role                 income  ContingencySimilarity
# 19               job_role           credit_score  ContingencySimilarity
# 20               job_role           savings_rate  ContingencySimilarity
# 21               job_role  existing_loan_balance  ContingencySimilarity
# 22               job_role        account_balance  ContingencySimilarity
# 23               job_role            joined_date  ContingencySimilarity
# 24        employment_type                 income  ContingencySimilarity
# 25        employment_type           credit_score  ContingencySimilarity
# 26        employment_type           savings_rate  ContingencySimilarity
# 27        employment_type  existing_loan_balance  ContingencySimilarity
# 28        employment_type        account_balance  ContingencySimilarity
# 29        employment_type            joined_date  ContingencySimilarity
# 30                 income           credit_score  CorrelationSimilarity
# 31                 income           savings_rate  CorrelationSimilarity
# 32                 income  existing_loan_balance  CorrelationSimilarity
# 33                 income        account_balance  CorrelationSimilarity
# 34                 income            joined_date  CorrelationSimilarity
# 35           credit_score           savings_rate  CorrelationSimilarity
# 36           credit_score  existing_loan_balance  CorrelationSimilarity
# 37           credit_score        account_balance  CorrelationSimilarity
# 38           credit_score            joined_date  CorrelationSimilarity
# 39           savings_rate  existing_loan_balance  CorrelationSimilarity
# 40           savings_rate        account_balance  CorrelationSimilarity
# 41           savings_rate            joined_date  CorrelationSimilarity
# 42  existing_loan_balance        account_balance  CorrelationSimilarity
# 43  existing_loan_balance            joined_date  CorrelationSimilarity
# 44        account_balance            joined_date  CorrelationSimilarity
#
#        Score  Real Correlation  Synthetic Correlation
# 0   0.827600               NaN                    NaN
# 1   0.832700               NaN                    NaN
# 2   0.840300               NaN                    NaN
# 3   0.963443          0.014877              -0.058237
# 4   0.984066         -0.016100               0.015767
# 5   0.955281         -0.023666               0.065772
# 6   0.991505         -0.010513              -0.027504
# 7   0.997087          0.026408               0.032234
# 8   0.981662          0.008481               0.045157
# 9   0.855700               NaN                    NaN
# 10  0.789700               NaN                    NaN
# 11  0.802700               NaN                    NaN
# 12  0.694200               NaN                    NaN
# 13  0.823900               NaN                    NaN
# 14  0.785200               NaN                    NaN
# 15  0.801900               NaN                    NaN
# 16  0.792800               NaN                    NaN
# 17  0.821400               NaN                    NaN
# 18  0.824300               NaN                    NaN
# 19  0.719500               NaN                    NaN
# 20  0.825900               NaN                    NaN
# 21  0.829900               NaN                    NaN
# 22  0.813600               NaN                    NaN
# 23  0.818000               NaN                    NaN
# 24  0.835100               NaN                    NaN
# 25  0.718300               NaN                    NaN
# 26  0.857900               NaN                    NaN
# 27  0.841700               NaN                    NaN
# 28  0.831900               NaN                    NaN
# 29  0.821000               NaN                    NaN
# 30  0.973222          0.043866              -0.009689
# 31  0.994055          0.013173               0.025064
# 32  0.993555         -0.041082              -0.028192
# 33  0.994168         -0.016048              -0.004385
# 34  0.986970          0.049443               0.075504
# 35  0.945566         -0.046126               0.062743
# 36  0.972797          0.015962              -0.038443
# 37  0.980611         -0.014339               0.024438
# 38  0.987386          0.023323              -0.001905
# 39  0.985810          0.007395               0.035776
# 40  0.999060         -0.019607              -0.017727
# 41  0.998410         -0.010495              -0.007316
# 42  0.989038         -0.012646               0.009278
# 43  0.982037         -0.026883               0.009042
# 44  0.962173          0.060807              -0.014847

# %%
# evaluate_hma.py
import os
import pandas as pd
from sdv.metadata import Metadata
from sdv.evaluation.multi_table import evaluate_quality

# ---------- File paths ----------
DOWNLOADS_DIR = os.path.join(os.path.expanduser("~"), "Downloads", "synthetic_data")

# Real (seed) tables
real_data = {
    'customers': pd.read_csv(os.path.join(DOWNLOADS_DIR, "customers.csv")),
    'transactions': pd.read_csv(os.path.join(DOWNLOADS_DIR, "transactions.csv")),
    'campaigns': pd.read_csv(os.path.join(DOWNLOADS_DIR, "campaign_events.csv"))
}

# Synthetic tables
synthetic_data = {
    'customers': pd.read_csv(os.path.join(DOWNLOADS_DIR, "customers_hma_10000.csv")),
    'transactions': pd.read_csv(os.path.join(DOWNLOADS_DIR, "transactions_hma_10000.csv")),
    'campaigns': pd.read_csv(os.path.join(DOWNLOADS_DIR, "campaigns_hma_10000.csv"))
}

# ---------- Build Metadata ----------
metadata = Metadata()
metadata.detect_table_from_dataframe('customers', real_data['customers'])
metadata.detect_table_from_dataframe('transactions', real_data['transactions'])
metadata.detect_table_from_dataframe('campaigns', real_data['campaigns'])

metadata.add_relationship(
    parent_table_name='customers',
    parent_primary_key='customer_id',
    child_table_name='transactions',
    child_foreign_key='customer_id'
)
metadata.add_relationship(
    parent_table_name='customers',
    parent_primary_key='customer_id',
    child_table_name='campaigns',
    child_foreign_key='customer_id'
)

# ---------- Evaluate ----------
score = evaluate_quality(
    real_data=real_data,
    synthetic_data=synthetic_data,
    metadata=metadata
)

print("Overall Multi-Table Quality Score:", score.get_score())
print("\nDetailed Breakdown:")
print("\nDetailed Breakdown:")

# Column Shapes (how realistic each column is)
print("\n📊 Column Shapes Details:")
print(score.get_details(property_name="Column Shapes"))

# Column Pair Trends (relationships within each table)
print("\n🔗 Column Pair Trends Details:")
print(score.get_details(property_name="Column Pair Trends"))

# Cardinality (how well parent/child row ratios are preserved)
print("\n🧩 Cardinality Details:")
print(score.get_details(property_name="Cardinality"))

# Intertable Trends (relationships between tables)
print("\n🔄 Intertable Trends Details:")
print(score.get_details(property_name="Intertable Trends"))
# Out:
# Generating report ...
#
# (1/4) Evaluating Column Shapes: |██████████| 19/19 [00:00<00:00, 59.77it/s]|
# Column Shapes Score: 87.13%
#
# (2/4) Evaluating Column Pair Trends: |██████████| 75/75 [00:00<00:00, 175.81it/s]|
# Column Pair Trends Score: 92.33%
#
# (3/4) Evaluating Cardinality: |██████████| 2/2 [00:00<00:00, 34.13it/s]|
# Cardinality Score: 93.3%
#
# (4/4) Evaluating Intertable Trends: |██████████| 84/84 [00:01<00:00, 58.50it/s]|
# Intertable Trends Score: 79.96%
#
# Overall Score (Average): 88.18%
#
# Overall Multi-Table Quality Score: 0.8817918022321913
#
# Detailed Breakdown:
#
# Detailed Breakdown:
#
# 📊 Column Shapes Details:
#            Table                 Column        Metric     Score
# 0      customers                    age  KSComplement  0.919900
# 1      customers                 gender  TVComplement  0.994300
# 2      customers               job_role  TVComplement  0.987100
# 3      customers        employment_type  TVComplement  0.991900
# 4      customers                 income  KSComplement  0.972000
# 5      customers           credit_score  KSComplement  0.988300
# 6      customers           savings_rate  KSComplement  0.976700
# 7      customers  existing_loan_balance  KSComplement  0.505000
# 8      customers        account_balance  KSComplement  0.988300
# 9      customers            joined_date  KSComplement  0.980200
# 10  transactions       transaction_date  KSComplement  0.580529
# 11  transactions               category  TVComplement  0.918087
# 12  transactions                 amount  KSComplement  0.473455
# 13     campaigns             event_date  KSComplement  1.000000
# 14     campaigns               response  TVComplement  0.793245
#
# 🔗 Column Pair Trends Details:
#            Table               Column 1               Column 2  \
# 0      customers                    age                 gender
# 1      customers                    age               job_role
# 2      customers                    age        employment_type
# 3      customers                    age                 income
# 4      customers                    age           credit_score
# 5      customers                    age           savings_rate
# 6      customers                    age  existing_loan_balance
# 7      customers                    age        account_balance
# 8      customers                    age            joined_date
# 9      customers                 gender               job_role
# 10     customers                 gender        employment_type
# 11     customers                 gender                 income
# 12     customers                 gender           credit_score
# 13     customers                 gender           savings_rate
# 14     customers                 gender  existing_loan_balance
# 15     customers                 gender        account_balance
# 16     customers                 gender            joined_date
# 17     customers               job_role        employment_type
# 18     customers               job_role                 income
# 19     customers               job_role           credit_score
# 20     customers               job_role           savings_rate
# 21     customers               job_role  existing_loan_balance
# 22     customers               job_role        account_balance
# 23     customers               job_role            joined_date
# 24     customers        employment_type                 income
# 25     customers        employment_type           credit_score
# 26     customers        employment_type           savings_rate
# 27     customers        employment_type  existing_loan_balance
# 28     customers        employment_type        account_balance
# 29     customers        employment_type            joined_date
# 30     customers                 income           credit_score
# 31     customers                 income           savings_rate
# 32     customers                 income  existing_loan_balance
# 33     customers                 income        account_balance
# 34     customers                 income            joined_date
# 35     customers           credit_score           savings_rate
# 36     customers           credit_score  existing_loan_balance
# 37     customers           credit_score        account_balance
# 38     customers           credit_score            joined_date
# 39     customers           savings_rate  existing_loan_balance
# 40     customers           savings_rate        account_balance
# 41     customers           savings_rate            joined_date
# 42     customers  existing_loan_balance        account_balance
# 43     customers  existing_loan_balance            joined_date
# 44     customers        account_balance            joined_date
# 45  transactions       transaction_date               category
# 46  transactions       transaction_date                 amount
# 47  transactions               category                 amount
# 48     campaigns             event_date               response
#
#                    Metric     Score  Real Correlation  Synthetic Correlation  \
# 0   ContingencySimilarity  0.906300               NaN                    NaN
# 1   ContingencySimilarity  0.880500               NaN                    NaN
# 2   ContingencySimilarity  0.900900               NaN                    NaN
# 3   CorrelationSimilarity  0.997653          0.014877               0.010183
# 4   CorrelationSimilarity  0.984145         -0.016100               0.015610
# 5   CorrelationSimilarity  0.995984         -0.023666              -0.031698
# 6   CorrelationSimilarity  0.997449         -0.010513              -0.015614
# 7   CorrelationSimilarity  0.997409          0.026408               0.031590
# 8   CorrelationSimilarity  0.987997          0.008481              -0.015525
# 9   ContingencySimilarity  0.975700               NaN                    NaN
# 10  ContingencySimilarity  0.972600               NaN                    NaN
# 11  ContingencySimilarity  0.939800               NaN                    NaN
# 12  ContingencySimilarity  0.955300               NaN                    NaN
# 13  ContingencySimilarity  0.951500               NaN                    NaN
# 14  ContingencySimilarity  0.764200               NaN                    NaN
# 15  ContingencySimilarity  0.948600               NaN                    NaN
# 16  ContingencySimilarity  0.957100               NaN                    NaN
# 17  ContingencySimilarity  0.960600               NaN                    NaN
# 18  ContingencySimilarity  0.916100               NaN                    NaN
# 19  ContingencySimilarity  0.929100               NaN                    NaN
# 20  ContingencySimilarity  0.914000               NaN                    NaN
# 21  ContingencySimilarity  0.753100               NaN                    NaN
# 22  ContingencySimilarity  0.923600               NaN                    NaN
# 23  ContingencySimilarity  0.923500               NaN                    NaN
# 24  ContingencySimilarity  0.943700               NaN                    NaN
# 25  ContingencySimilarity  0.945200               NaN                    NaN
# 26  ContingencySimilarity  0.953200               NaN                    NaN
# 27  ContingencySimilarity  0.768700               NaN                    NaN
# 28  ContingencySimilarity  0.944900               NaN                    NaN
# 29  ContingencySimilarity  0.954900               NaN                    NaN
# 30  CorrelationSimilarity  0.994452          0.043866               0.032770
# 31  CorrelationSimilarity  0.984167          0.013173              -0.018493
# 32  CorrelationSimilarity  0.987660         -0.041082              -0.016403
# 33  CorrelationSimilarity  0.998078         -0.016048              -0.012204
# 34  CorrelationSimilarity  0.999232          0.049443               0.050979
# 35  CorrelationSimilarity  0.998792         -0.046126              -0.043709
# 36  CorrelationSimilarity  0.997958          0.015962               0.020046
# 37  CorrelationSimilarity  0.996507         -0.014339              -0.007354
# 38  CorrelationSimilarity  0.997106          0.023323               0.017536
# 39  CorrelationSimilarity  0.988300          0.007395              -0.016005
# 40  CorrelationSimilarity  0.992868         -0.019607              -0.005343
# 41  CorrelationSimilarity  0.999489         -0.010495              -0.009474
# 42  CorrelationSimilarity  0.995416         -0.012646              -0.003477
# 43  CorrelationSimilarity  0.988572         -0.026883              -0.004028
# 44  CorrelationSimilarity  0.998668          0.060807               0.058142
# 45  ContingencySimilarity  0.281800               NaN                    NaN
# 46  CorrelationSimilarity  0.990533          0.003772               0.022706
# 47  ContingencySimilarity  0.183340               NaN                    NaN
# 48  ContingencySimilarity       NaN               NaN                    NaN
#
#                                                 Error
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48  ValueError: Too many bins for data range. Cann...
#
# 🧩 Cardinality Details:
#     Child Table Parent Table  Foreign Key                      Metric   Score
# 0  transactions    customers  customer_id  CardinalityShapeSimilarity  0.9729
# 1     campaigns    customers  customer_id  CardinalityShapeSimilarity  0.8931
#
# 🔄 Intertable Trends Details:
#    Parent Table   Child Table  Foreign Key               Column 1  \
# 0     customers  transactions  customer_id                    age
# 1     customers  transactions  customer_id                    age
# 2     customers  transactions  customer_id                    age
# 3     customers  transactions  customer_id                 gender
# 4     customers  transactions  customer_id                 gender
# 5     customers  transactions  customer_id                 gender
# 6     customers  transactions  customer_id               job_role
# 7     customers  transactions  customer_id               job_role
# 8     customers  transactions  customer_id               job_role
# 9     customers  transactions  customer_id        employment_type
# 10    customers  transactions  customer_id        employment_type
# 11    customers  transactions  customer_id        employment_type
# 12    customers  transactions  customer_id                 income
# 13    customers  transactions  customer_id                 income
# 14    customers  transactions  customer_id                 income
# 15    customers  transactions  customer_id           credit_score
# 16    customers  transactions  customer_id           credit_score
# 17    customers  transactions  customer_id           credit_score
# 18    customers  transactions  customer_id           savings_rate
# 19    customers  transactions  customer_id           savings_rate
# 20    customers  transactions  customer_id           savings_rate
# 21    customers  transactions  customer_id  existing_loan_balance
# 22    customers  transactions  customer_id  existing_loan_balance
# 23    customers  transactions  customer_id  existing_loan_balance
# 24    customers  transactions  customer_id        account_balance
# 25    customers  transactions  customer_id        account_balance
# 26    customers  transactions  customer_id        account_balance
# 27    customers  transactions  customer_id            joined_date
# 28    customers  transactions  customer_id            joined_date
# 29    customers  transactions  customer_id            joined_date
# 30    customers     campaigns  customer_id                    age
# 31    customers     campaigns  customer_id                    age
# 32    customers     campaigns  customer_id                 gender
# 33    customers     campaigns  customer_id                 gender
# 34    customers     campaigns  customer_id               job_role
# 35    customers     campaigns  customer_id               job_role
# 36    customers     campaigns  customer_id        employment_type
# 37    customers     campaigns  customer_id        employment_type
# 38    customers     campaigns  customer_id                 income
# 39    customers     campaigns  customer_id                 income
# 40    customers     campaigns  customer_id           credit_score
# 41    customers     campaigns  customer_id           credit_score
# 42    customers     campaigns  customer_id           savings_rate
# 43    customers     campaigns  customer_id           savings_rate
# 44    customers     campaigns  customer_id  existing_loan_balance
# 45    customers     campaigns  customer_id  existing_loan_balance
# 46    customers     campaigns  customer_id        account_balance
# 47    customers     campaigns  customer_id        account_balance
# 48    customers     campaigns  customer_id            joined_date
# 49    customers     campaigns  customer_id            joined_date
#
#             Column 2                 Metric     Score  Real Correlation  \
# 0   transaction_date  CorrelationSimilarity  0.988054          0.001578
# 1           category  ContingencySimilarity  0.875640               NaN
# 2             amount  CorrelationSimilarity  0.996130         -0.004683
# 3   transaction_date  ContingencySimilarity  0.279260               NaN
# 4           category  ContingencySimilarity  0.917480               NaN
# 5             amount  ContingencySimilarity  0.183400               NaN
# 6   transaction_date  ContingencySimilarity  0.281560               NaN
# 7           category  ContingencySimilarity  0.913920               NaN
# 8             amount  ContingencySimilarity  0.180780               NaN
# 9   transaction_date  ContingencySimilarity  0.282520               NaN
# 10          category  ContingencySimilarity  0.917280               NaN
# 11            amount  ContingencySimilarity  0.182820               NaN
# 12  transaction_date  CorrelationSimilarity  0.990742          0.007577
# 13          category  ContingencySimilarity  0.903520               NaN
# 14            amount  CorrelationSimilarity  0.991155          0.000873
# 15  transaction_date  CorrelationSimilarity  0.982102          0.003992
# 16          category  ContingencySimilarity  0.908340               NaN
# 17            amount  CorrelationSimilarity  0.998943         -0.007248
# 18  transaction_date  CorrelationSimilarity  0.992742          0.000731
# 19          category  ContingencySimilarity  0.910060               NaN
# 20            amount  CorrelationSimilarity  0.979247          0.004518
# 21  transaction_date  CorrelationSimilarity  0.981439          0.004329
# 22          category  ContingencySimilarity  0.763120               NaN
# 23            amount  CorrelationSimilarity  0.986745         -0.007598
# 24  transaction_date  CorrelationSimilarity  0.980876         -0.003053
# 25          category  ContingencySimilarity  0.909600               NaN
# 26            amount  CorrelationSimilarity  0.984806          0.004239
# 27  transaction_date  CorrelationSimilarity  0.999059          0.001631
# 28          category  ContingencySimilarity  0.909420               NaN
# 29            amount  CorrelationSimilarity  0.983533          0.004876
# 30        event_date  CorrelationSimilarity       NaN               NaN
# 31          response  ContingencySimilarity  0.775497               NaN
# 32        event_date  ContingencySimilarity       NaN               NaN
# 33          response  ContingencySimilarity  0.793245               NaN
# 34        event_date  ContingencySimilarity       NaN               NaN
# 35          response  ContingencySimilarity  0.793245               NaN
# 36        event_date  ContingencySimilarity       NaN               NaN
# 37          response  ContingencySimilarity  0.793245               NaN
# 38        event_date  CorrelationSimilarity       NaN               NaN
# 39          response  ContingencySimilarity  0.792980               NaN
# 40        event_date  CorrelationSimilarity       NaN               NaN
# 41          response  ContingencySimilarity  0.790861               NaN
# 42        event_date  CorrelationSimilarity       NaN               NaN
# 43          response  ContingencySimilarity  0.793245               NaN
# 44        event_date  CorrelationSimilarity       NaN               NaN
# 45          response  ContingencySimilarity  0.712450               NaN
# 46        event_date  CorrelationSimilarity       NaN               NaN
# 47          response  ContingencySimilarity  0.793146               NaN
# 48        event_date  CorrelationSimilarity       NaN               NaN
# 49          response  ContingencySimilarity  0.793212               NaN
#
#     Synthetic Correlation                                              Error
# 0               -0.022314                                               None
# 1                     NaN                                               None
# 2               -0.012424                                               None
# 3                     NaN                                               None
# 4                     NaN                                               None
# 5                     NaN                                               None
# 6                     NaN                                               None
# 7                     NaN                                               None
# 8                     NaN                                               None
# 9                     NaN                                               None
# 10                    NaN                                               None
# 11                    NaN                                               None
# 12               0.026094                                               None
# 13                    NaN                                               None
# 14              -0.016816                                               None
# 15              -0.031804                                               None
# 16                    NaN                                               None
# 17              -0.005134                                               None
# 18              -0.013786                                               None
# 19                    NaN                                               None
# 20               0.046025                                               None
# 21              -0.032794                                               None
# 22                    NaN                                               None
# 23               0.018911                                               None
# 24               0.035195                                               None
# 25                    NaN                                               None
# 26               0.034626                                               None
# 27               0.003514                                               None
# 28                    NaN                                               None
# 29               0.037811                                               None
# 30                    NaN  ConstantInputError: The real data in column 'c...
# 31                    NaN                                               None
# 32                    NaN  ValueError: Too many bins for data range. Cann...
# 33                    NaN                                               None
# 34                    NaN  ValueError: Too many bins for data range. Cann...
# 35                    NaN                                               None
# 36                    NaN  ValueError: Too many bins for data range. Cann...
# 37                    NaN                                               None
# 38                    NaN  ConstantInputError: The real data in column 'c...
# 39                    NaN                                               None
# 40                    NaN  ConstantInputError: The real data in column 'c...
# 41                    NaN                                               None
# 42                    NaN  ConstantInputError: The real data in column 'c...
# 43                    NaN                                               None
# 44                    NaN  ConstantInputError: The real data in column 'c...
# 45                    NaN                                               None
# 46                    NaN  ConstantInputError: The real data in column 'c...
# 47                    NaN                                               None
# 48                    NaN  ConstantInputError: The real data in column 'c...
# 49                    NaN                                               None

# %%
S
